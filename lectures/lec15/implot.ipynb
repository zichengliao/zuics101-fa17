# %%
import numpy as np
img = np.loadtxt('img/lena.txt', delimiter=',')

# %%
img.shape
# Out:
# (225, 225)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)
plt.set_cmap('gray')
plt.show()
